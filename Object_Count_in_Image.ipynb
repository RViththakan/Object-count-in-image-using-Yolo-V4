# %%
pip install cvlib
# Out:
# Collecting cvlib
#   Downloading cvlib-0.2.7.tar.gz (13.1 MB)
#      ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#      --------------------------------------- 0.0/13.1 MB 326.8 kB/s eta 0:00:40
#      --------------------------------------- 0.1/13.1 MB 525.1 kB/s eta 0:00:25
#       -------------------------------------- 0.2/13.1 MB 748.1 kB/s eta 0:00:18
#      - -------------------------------------- 0.4/13.1 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------- 0.7/13.1 MB 2.1 MB/s eta 0:00:07
#      --- ------------------------------------ 1.0/13.1 MB 2.8 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.4/13.1 MB 3.3 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.7/13.1 MB 3.7 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.9/13.1 MB 3.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.3/13.1 MB 4.2 MB/s eta 0:00:03
#      ------- -------------------------------- 2.5/13.1 MB 4.1 MB/s eta 0:00:03
#      -------- ------------------------------- 2.8/13.1 MB 4.4 MB/s eta 0:00:03
#      --------- ------------------------------ 3.0/13.1 MB 4.4 MB/s eta 0:00:03
#      --------- ------------------------------ 3.2/13.1 MB 4.4 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.5/13.1 MB 4.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.7/13.1 MB 4.4 MB/s eta 0:00:03
#      ------------ --------------------------- 4.1/13.1 MB 4.6 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/13.1 MB 4.9 MB/s eta 0:00:02
#      --------------- ------------------------ 5.0/13.1 MB 5.0 MB/s eta 0:00:02
#      --------------- ------------------------ 5.2/13.1 MB 5.0 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.6/13.1 MB 5.1 MB/s eta 0:00:02
#      ------------------ --------------------- 6.1/13.1 MB 5.3 MB/s eta 0:00:02
#      ------------------ --------------------- 6.1/13.1 MB 5.2 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/13.1 MB 5.4 MB/s eta 0:00:02
#      --------------------- ------------------ 7.0/13.1 MB 5.4 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.4/13.1 MB 5.5 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.8/13.1 MB 5.5 MB/s eta 0:00:01
#      ------------------------- -------------- 8.3/13.1 MB 5.8 MB/s eta 0:00:01
#      -------------------------- ------------- 8.6/13.1 MB 5.8 MB/s eta 0:00:01
#      --------------------------- ------------ 9.1/13.1 MB 5.9 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.5/13.1 MB 6.0 MB/s eta 0:00:01
#      ------------------------------ --------- 10.1/13.1 MB 6.1 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/13.1 MB 7.1 MB/s eta 0:00:01
#      --------------------------------- ------ 10.9/13.1 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.2/13.1 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.4/13.1 MB 7.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.7/13.1 MB 7.0 MB/s eta 0:00:01
#      ------------------------------------ --- 12.1/13.1 MB 7.0 MB/s eta 0:00:01
#      ------------------------------------- -- 12.3/13.1 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------  12.9/13.1 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------------  13.1/13.1 MB 7.1 MB/s eta 0:00:01
#      ---------------------------------------- 13.1/13.1 MB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\viththakan\anaconda3\lib\site-packages (from cvlib) (1.26.3)
# Collecting progressbar (from cvlib)
#   Downloading progressbar-2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\users\viththakan\anaconda3\lib\site-packages (from cvlib) (2.31.0)
# Requirement already satisfied: pillow in c:\users\viththakan\anaconda3\lib\site-packages (from cvlib) (10.0.1)
# Requirement already satisfied: imageio in c:\users\viththakan\anaconda3\lib\site-packages (from cvlib) (2.31.4)
# Collecting imutils (from cvlib)
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\viththakan\anaconda3\lib\site-packages (from requests->cvlib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\viththakan\anaconda3\lib\site-packages (from requests->cvlib) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\viththakan\anaconda3\lib\site-packages (from requests->cvlib) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\viththakan\anaconda3\lib\site-packages (from requests->cvlib) (2023.11.17)
# Building wheels for collected packages: cvlib, imutils, progressbar
#   Building wheel for cvlib (setup.py): started
#   Building wheel for cvlib (setup.py): finished with status 'done'
#   Created wheel for cvlib: filename=cvlib-0.2.7-py3-none-any.whl size=10046378 sha256=ac1d9819909f230d06dc5a5506da0b1604637074d3d4bef0ad434a9c61262146
#   Stored in directory: c:\users\viththakan\appdata\local\pip\cache\wheels\47\ea\1c\d618f916b503769662fc15debfdefbf7bc43f014465c3bb7c7
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25854 sha256=dd0a15810b5840f6cff090355acf9a7a84c873cbfd1129a8ba53f263b154f235
#   Stored in directory: c:\users\viththakan\appdata\local\pip\cache\wheels\31\d0\2c\87ce38f6052879e5b7b18f0f8b4a10ad2a9d210e908d449f16
#   Building wheel for progressbar (setup.py): started
#   Building wheel for progressbar (setup.py): finished with status 'done'
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12084 sha256=23d106a8bd82e86e191046e66ccd5270c90bd5b428477081f4bf3acfbdfc28c5
#   Stored in directory: c:\users\viththakan\appdata\local\pip\cache\wheels\8d\bb\b2\5353b966ac6f3c5e1000629a9a5f6aed41794487f551e32efc
# Successfully built cvlib imutils progressbar
# Installing collected packages: progressbar, imutils, cvlib
# Successfully installed cvlib-0.2.7 imutils-0.5.4 progressbar-2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

image = cv2.imread("cars.png")
box, label, count = cv.detect_common_objects(image)
output = draw_bbox(image, box, label, count)
plt.imshow(output)
plt.show()
print("Number of cars in this image are " +str(label.count('car')))
# Out:
# WARNING:tensorflow:From C:\Users\Viththakan\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Downloading yolov4.cfg from https://raw.githubusercontent.com/AlexeyAB/darknet/master/cfg/yolov4.cfg
#   0% |                                                                        |
# Downloading yolov4.weights from https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights
#  99% |####################################################################### |
# Downloading yolov3_classes.txt from https://github.com/arunponnusamy/object-detection-opencv/raw/master/yolov3.txt
# 100% |                                                                        |
# Number of cars in this image are 11
